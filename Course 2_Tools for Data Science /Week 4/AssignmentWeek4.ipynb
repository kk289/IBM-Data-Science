# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Name: Kevil Khadka<br>Desired Job: Data Analyst/Data Programmer</strong>

# %% [markdown]
# <em>I am interested in data science or programming langauges because I like data and love to play with data.</em>

# %% [markdown]
# <h3>Calculate the sum of 1 and 1</h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <hr>
# <ol>
#   <li>IBM-Data Science</li>
#   <li>Tools for Data Science</li>
# </ol>
# </hr>
#
# <ul>
#     <li>Jupyter Notebook Assignment</li>
# </ul>
#
# <a href=https://github.com/kk289/IBM-Data-Science>My Github Profile </a>
#
#
#
#
#
# <table style="width:50%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>X</td>
#     <td>Y</td>
#     <td>1</td>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>B</td>
#     <td>2</td>
#   </tr>
# </table>
